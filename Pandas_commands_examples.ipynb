# %% [markdown]
# <a href="https://colab.research.google.com/github/A9594/Pandas_all-codes/blob/main/Pandas_commands_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df) #to view the structure of the data
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()  #to view up 5 records
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()  #to view bottom 5 records
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.head(12)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778

# %%
df.isnull() #to check the null values
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.columns   #name of our columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.dtypes    #to check the data types
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.describe()  #basic stats information about numerical columns in dataset
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.describe(include='all')
# Out:
#         rank discipline        phd    service   sex         salary
# count     78         78  78.000000  78.000000    78      78.000000
# unique     3          2        NaN        NaN     2            NaN
# top     Prof          B        NaN        NaN  Male            NaN
# freq      46         42        NaN        NaN    39            NaN
# mean     NaN        NaN  19.705128  15.051282   NaN  108023.782051
# std      NaN        NaN  12.498425  12.139768   NaN   28293.661022
# min      NaN        NaN   1.000000   0.000000   NaN   57800.000000
# 25%      NaN        NaN  10.250000   5.250000   NaN   88612.500000
# 50%      NaN        NaN  18.500000  14.500000   NaN  104671.000000
# 75%      NaN        NaN  27.750000  20.750000   NaN  126774.750000
# max      NaN        NaN  56.000000  51.000000   NaN  186960.000000

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df['phd'].value_counts()
# Out:
# phd
# 4     6
# 17    5
# 20    5
# 12    5
# 23    4
# 18    4
# 29    3
# 25    3
# 28    3
# 3     2
# 5     2
# 11    2
# 7     2
# 45    2
# 10    2
# 2     2
# 13    2
# 19    2
# 8     2
# 35    2
# 36    2
# 39    2
# 14    1
# 26    1
# 56    1
# 30    1
# 27    1
# 22    1
# 9     1
# 21    1
# 38    1
# 33    1
# 1     1
# 51    1
# 40    1
# 24    1
# Name: count, dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
# 30    107008
# 31    155750
# 32    103275
# 33    120000
# 34    119800
# 35    126933
# 36    146856
# 37    102000
# 38     91000
# 39    129000
# 40    137000
# 41     74830
# 42     80225
# 43     77000
# 44    151768
# 45    140096
# 46     74692
# 47    103613
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# ...

# %%
df['salary'].mean()  #to find the mean value
# Out:
# 108023.78205128205

# %%
df['salary'].median()  #to find the median value
# Out:
# 104671.0

# %%
df['salary'].mode()   #to find the mode value
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].std()  #to find the standard deviation value
# Out:
# 28293.66102226417

# %%
df['salary'].skew()  #to find the skewness value
# Out:
# 0.45210256755588096

# %%
df['salary'].kurt()  #to find the kurtosis value
# Out:
# -0.4017126758820546

# %%
df['salary'].kurtosis()
# Out:
# -0.4017126758820546

# %%
df[['salary','phd']].mean()
# Out:
# salary    108023.782051
# phd           19.705128
# dtype: float64

# %%
df['salary']>150000
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44     True
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# ...

# %%
df[df['salary']>150000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750
# 44  Prof          B   23       19  Female  151768
# 72  Prof          B   24       15  Female  161101

# %%
df.groupby('rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
#drop null values
df=df.dropna()
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df=df.drop(columns='rank', axis=1)  # to drop column in dataset
df
# Out:
#    discipline  phd  service     sex  salary
# 0           B   56       49    Male  186960
# 1           A   12        6    Male   93000
# 2           A   23       20    Male  110515
# 3           A   40       31    Male  131205
# 4           B   20       18    Male  104800
# 5           A   20       20    Male  122400
# 6           A   20       17    Male   81285
# 7           A   18       18    Male  126300
# 8           A   29       19    Male   94350
# 9           A   51       51    Male   57800
# 10          B   39       33    Male  128250
# 11          B   23       23    Male  134778
# 12          B    1        0    Male   88000
# 13          B   35       33    Male  162200
# 14          B   25       19    Male  153750
# 15          B   17        3    Male  150480
# 16          B    8        3    Male   75044
# 17          B    4        0    Male   92000
# 18          A   19        7    Male  107300
# 19          A   29       27    Male  150500
# ...

# %%
df=df.drop(columns='discipline', axis=1)
df
# Out:
#     phd  service     sex  salary
# 0    56       49    Male  186960
# 1    12        6    Male   93000
# 2    23       20    Male  110515
# 3    40       31    Male  131205
# 4    20       18    Male  104800
# 5    20       20    Male  122400
# 6    20       17    Male   81285
# 7    18       18    Male  126300
# 8    29       19    Male   94350
# 9    51       51    Male   57800
# 10   39       33    Male  128250
# 11   23       23    Male  134778
# 12    1        0    Male   88000
# 13   35       33    Male  162200
# 14   25       19    Male  153750
# 15   17        3    Male  150480
# 16    8        3    Male   75044
# 17    4        0    Male   92000
# 18   19        7    Male  107300
# 19   29       27    Male  150500
# 20    4        4    Male   92000
# 21   33       30    Male  103106
# 22    4        2    Male   73000
# 23    2        0    Male   85000
# 24   30       23    Male   91100
# 25   35       31    Male   99418
# 26   38       19    Male  148750
# ...

# %%
#maximum value in each column in dataset
df.max()
# Out:
# phd            56
# service        51
# sex          Male
# salary     186960
# dtype: object

# %%
#minimum value in each column in dataset
df.min()
# Out:
# phd             1
# service         0
# sex        Female
# salary      57800
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
univ = pd.read_csv('Universities.csv')

# %%
univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
univ.shape
# Out:
# (25, 7)

# %%
plt.hist(univ['Accept'])
plt.xlabel('Acceptance')
plt.ylabel('count')
plt.title('Histogram of acceptance')
plt.show()

# %%
plt.hist(univ['SAT'])
plt.xlabel('SAT')
plt.ylabel('count')
plt.title('Histogram of SAT')
plt.show()

# %%
sn.histplot(univ['Accept'])
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
sn.distplot(univ['Accept'])
plt.show()

# %%
plt.plot(univ['Accept'],univ['Top10'])
plt.show()

# %%
plt.plot(univ['Accept'],univ['Top10'], 'rs')
plt.xlabel('Accept')
plt.ylabel('Top10')
plt.title('Scatterplot of Accept vs Top10')
plt.show()
help(plt.plot)  # it will help us to learn graph
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
sn.pairplot(univ)

# %%
sn.pairplot(univ.iloc[:,0:3])

# %%
plt.boxplot(univ['Accept'])
plt.show()
